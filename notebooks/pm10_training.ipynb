# %%
# If needed in Colab:
# !pip install -q tensorflow scikit-learn pandas matplotlib numpy

import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from datetime import datetime
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.ensemble import RandomForestRegressor

print("TensorFlow:", tf.__version__)
print("GPU available:", len(tf.config.list_physical_devices('GPU')) > 0)
# Out:
# TensorFlow: 2.19.0
# GPU available: True

# %%
CSV_PATH = '/content/skopje_air_quality_historical_CLEANED.csv'   # change if needed
TARGET_COL = 'pm10'
LOOKBACK = 48
HORIZON = 24
TOP_K_FEATURES = 15
USE_RF_SELECTION = True
EPOCHS = 40
BATCH_SIZE = 128
LR = 3e-4
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %%
df = pd.read_csv(CSV_PATH)
df.columns = df.columns.str.strip()

if 'datetime' not in df.columns:
    raise ValueError("Expected 'datetime' column in CSV.")

df['datetime'] = pd.to_datetime(df['datetime'])
df = df.sort_values('datetime').set_index('datetime')

if 'timestamp' in df.columns:
    df = df.drop(columns=['timestamp'])

# add cyclical time if missing
if 'hour_sin' not in df.columns or 'hour_cos' not in df.columns:
    hours = df.index.hour
    df['hour_sin'] = np.sin(2*np.pi*hours/24)
    df['hour_cos'] = np.cos(2*np.pi*hours/24)

if 'day_sin' not in df.columns or 'day_cos' not in df.columns:
    days = df.index.dayofweek
    df['day_sin'] = np.sin(2*np.pi*days/7)
    df['day_cos'] = np.cos(2*np.pi*days/7)

# %%
def add_dynamic_features(dfin: pd.DataFrame):
    d = dfin.copy()
    base_cols = ['pm10', 'pm2_5', 'aqi', 'co', 'no2']
    for col in base_cols:
        if col not in d.columns:
            continue
        d[f'{col}_diff1'] = d[col].diff(1)
        d[f'{col}_diff3'] = d[col].diff(3)
        d[f'{col}_diff6'] = d[col].diff(6)
        for w in [3, 6, 12, 24]:
            d[f'{col}_roll{w}_mean'] = d[col].rolling(w).mean()
            d[f'{col}_roll{w}_std'] = d[col].rolling(w).std()

    eps = 1e-6
    if 'pm10' in d.columns:
        d['pm10_mom24'] = d['pm10'] / (d['pm10_roll24_mean'] + eps)
        d['pm10_absdiff1'] = np.abs(d['pm10_diff1'])
        d['pm10_absdiff3'] = np.abs(d['pm10_diff3'])

    d = d.dropna()
    return d

df_feat = add_dynamic_features(df)
print("Feature-engineered shape:", df_feat.shape)
# Out:
# Feature-engineered shape: (46656, 67)

# %%
def select_features_for_pm10(
    df_features: pd.DataFrame,
    target_col: str = 'pm10',
    top_k: int = 15,
    force_keep=None,
    random_state: int = 42
):
    if force_keep is None:
        force_keep = ['pm10', 'pm2_5', 'aqi', 'hour_sin', 'hour_cos', 'day_sin', 'day_cos']

    d = df_features.copy().dropna()

    # one-step ahead target for ranking
    y_next = d[target_col].shift(-1)
    X = d.drop(columns=[target_col])
    data = pd.concat([X, y_next.rename('y_next')], axis=1).dropna()

    X = data.drop(columns=['y_next'])
    y = data['y_next']

    split = int(len(X) * 0.8)
    X_train, y_train = X.iloc[:split], y.iloc[:split]

    rf = RandomForestRegressor(
        n_estimators=300,
        max_depth=12,
        min_samples_leaf=5,
        random_state=random_state,
        n_jobs=-1
    )
    rf.fit(X_train, y_train)

    imp = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)

    selected = []
    # force keep core first
    for f in force_keep:
        if f in d.columns and f not in selected:
            selected.append(f)

    # fill with top important
    for f in imp.index:
        if f not in selected:
            selected.append(f)
        if len(selected) >= top_k:
            break

    # ensure target input included
    if target_col not in selected:
        selected = [target_col] + selected
    else:
        # move target to front
        selected = [target_col] + [c for c in selected if c != target_col]

    selected = selected[:top_k]
    return selected, imp

manual_features = [
    'pm10', 'pm2_5', 'aqi',
    'hour_sin', 'hour_cos', 'day_sin', 'day_cos',
    'pm10_diff1', 'pm10_diff3', 'pm10_absdiff1',
    'pm10_roll3_std', 'pm2_5_diff1', 'co_diff1'
]
manual_features = [c for c in manual_features if c in df_feat.columns]

if USE_RF_SELECTION:
    force_core = ['pm10', 'pm2_5', 'aqi', 'hour_sin', 'hour_cos', 'day_sin', 'day_cos']
    selected_cols, importance = select_features_for_pm10(
        df_features=df_feat,
        target_col=TARGET_COL,
        top_k=TOP_K_FEATURES,
        force_keep=force_core,
        random_state=SEED
    )
    print("\nSelected features (RF):", selected_cols)
    print("\nTop importances:")
    display(importance.head(20))
else:
    selected_cols = manual_features
    print("\nSelected features (manual):", selected_cols)

# optional safeguard: remove dominant rolling mean if too smoothing
if 'pm10_roll3_mean' in selected_cols:
    # keep it only if you want; comment this out if needed
    print("\nNote: removing pm10_roll3_mean to reduce mean-regression risk.")
    selected_cols = [c for c in selected_cols if c != 'pm10_roll3_mean']
    # ensure still enough features
    for c in manual_features:
        if c not in selected_cols:
            selected_cols.append(c)
        if len(selected_cols) >= min(TOP_K_FEATURES, 15):
            break

df_selected = df_feat[selected_cols].dropna()
print("\nFinal selected feature count:", len(df_selected.columns))
print(df_selected.columns.tolist())
# Out:
# Selected features (RF): ['pm10', 'pm2_5', 'aqi', 'hour_sin', 'hour_cos', 'day_sin', 'day_cos', 'pm10_roll3_mean', 'pm10_diff1', 'pm10_absdiff1', 'pm2_5_diff1', 'co_diff3', 'pm10_roll3_std', 'co_diff1', 'pm10_diff3']
#
# Top importances:
# pm10_roll3_mean     0.833567
# pm2_5               0.136237
# pm10_diff1          0.015482
# pm10_absdiff1       0.002638
# pm2_5_diff1         0.001473
# hour_cos            0.001129
# hour_sin            0.001004
# co_diff3            0.000825
# pm10_roll3_std      0.000764
# co_diff1            0.000585
# pm10_diff3          0.000458
# pm2_5_roll3_std     0.000457
# co_diff6            0.000297
# no2_diff1           0.000242
# pm2_5_roll3_mean    0.000230
# pm10_mom24          0.000218
# no2_diff3           0.000215
# pm10_roll6_mean     0.000205
# pm2_5_diff3         0.000204
# co_roll6_mean       0.000200
# dtype: float64
# Note: removing pm10_roll3_mean to reduce mean-regression risk.
#
# Final selected feature count: 14
# ['pm10', 'pm2_5', 'aqi', 'hour_sin', 'hour_cos', 'day_sin', 'day_cos', 'pm10_diff1', 'pm10_absdiff1', 'pm2_5_diff1', 'co_diff3', 'pm10_roll3_std', 'co_diff1', 'pm10_diff3']

# %%
feature_cols = list(df_selected.columns)
if TARGET_COL not in feature_cols:
    raise ValueError(f"TARGET_COL '{TARGET_COL}' missing from selected features.")

target_idx = feature_cols.index(TARGET_COL)

scaler = RobustScaler()
data_scaled = scaler.fit_transform(df_selected.values)

def make_sequences(data, target_col_idx, lookback=48, horizon=24):
    X, y = [], []
    for i in range(lookback, len(data) - horizon + 1):
        X.append(data[i-lookback:i, :])
        y.append(data[i:i+horizon, target_col_idx])
    return np.array(X), np.array(y)

X, y = make_sequences(data_scaled, target_idx, LOOKBACK, HORIZON)
print("X shape:", X.shape, "y shape:", y.shape)

# chronological split: 70/15/15
n = len(X)
n_train = int(n * 0.70)
n_val = int(n * 0.15)

X_train, y_train = X[:n_train], y[:n_train]
X_val, y_val = X[n_train:n_train+n_val], y[n_train:n_train+n_val]
X_test, y_test = X[n_train+n_val:], y[n_train+n_val:]

print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape, y_val.shape)
print("Test :", X_test.shape, y_test.shape)
# Out:
# X shape: (46585, 48, 14) y shape: (46585, 24)
# Train: (32609, 48, 14) (32609, 24)
# Val  : (6987, 48, 14) (6987, 24)
# Test : (6989, 48, 14) (6989, 24)

# %%
class PeakRampLoss(tf.keras.losses.Loss):
    def __init__(self, q75, peak_w=1.8, ramp_w=0.8, name='peak_ramp_loss'):
        super().__init__(name=name)
        self.q75 = tf.constant(q75, dtype=tf.float32)
        self.peak_w = peak_w
        self.ramp_w = ramp_w

    def call(self, y_true, y_pred):
        abs_err = tf.abs(y_true - y_pred)

        # peak emphasis
        peak_mask = tf.cast(y_true >= self.q75, tf.float32)
        w_peak = 1.0 + peak_mask * (self.peak_w - 1.0)

        # ramp emphasis (change magnitude)
        dy_true = tf.abs(y_true[:, 1:] - y_true[:, :-1])
        dy_true = tf.concat([dy_true[:, :1], dy_true], axis=1)
        w_ramp = 1.0 + self.ramp_w * tf.tanh(dy_true)

        w = w_peak * w_ramp
        return tf.reduce_mean(w * abs_err)

# %%
from tensorflow.keras import layers, Model, regularizers

def build_lean_model(lookback, n_features, horizon):
    inp = layers.Input(shape=(lookback, n_features))

    x = layers.Conv1D(
        filters=48, kernel_size=3, padding='causal', activation='relu',
        kernel_regularizer=regularizers.l2(1e-4)
    )(inp)
    x = layers.Dropout(0.20)(x)

    x = layers.Bidirectional(
        layers.LSTM(48, return_sequences=True, dropout=0.15, recurrent_dropout=0.0)
    )(x)

    # Keras-safe attention pooling
    score = layers.Dense(1, activation='tanh')(x)       # (B,T,1)
    score = layers.Softmax(axis=1)(score)               # (B,T,1)
    weighted = layers.Multiply()([x, score])            # (B,T,F)
    ctx = layers.Lambda(lambda t: tf.reduce_sum(t, axis=1))(weighted)  # (B,F)

    x = layers.Dense(96, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(ctx)
    x = layers.Dropout(0.25)(x)
    out = layers.Dense(horizon)(x)

    return Model(inp, out)

q75 = np.quantile(y_train, 0.75).astype(np.float32)
loss_fn = PeakRampLoss(q75=q75, peak_w=1.8, ramp_w=0.8)

model = build_lean_model(LOOKBACK, X_train.shape[-1], HORIZON)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR, clipnorm=1.0),
    loss=loss_fn,
    metrics=[tf.keras.metrics.MeanAbsoluteError(name='mae')]
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 48, 14)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 48, 48)    │      2,064 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 48, 48)    │          0 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 48, 96)    │     37,248 │ dropout[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 48, 1)     │         97 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax (Softmax)   │ (None, 48, 1)     │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 48, 96)    │          0 │ bidirectional[0]… │
# │                     │                   │            │ softmax[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 96)        │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 96)        │      9,312 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 96)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 24)        │      2,328 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 51,049 (199.41 KB)
#  Trainable params: 51,049 (199.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=4, min_lr=5e-6, verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=10, restore_best_weights=True, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        '/content/best_lean_pm10.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/40
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2652 - mae: 0.7368
# Epoch 1: val_loss improved from None to 1.03894, saving model to /content/best_lean_pm10.keras
#
# Epoch 1: finished saving model to /content/best_lean_pm10.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 1.0809 - mae: 0.6522 - val_loss: 1.0389 - val_mae: 0.6109 - learning_rate: 3.0000e-04
# Epoch 2/40
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8830 - mae: 0.5521
# Epoch 2: val_loss improved from 1.03894 to 1.00214, saving model to /content/best_lean_pm10.keras
#
# Epoch 2: finished saving model to /content/best_lean_pm10.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.8731 - mae: 0.5451 - val_loss: 1.0021 - val_mae: 0.5890 - learning_rate: 3.0000e-04
# Epoch 3/40
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8520 - mae: 0.5330
# Epoch 3: val_loss improved from 1.00214 to 0.99118, saving model to /content/best_lean_pm10.keras
#
# Epoch 3: finished saving model to /content/best_lean_pm10.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8450 - mae: 0.5286 - val_loss: 0.9912 - val_mae: 0.5803 - learning_rate: 3.0000e-04
# Epoch 4/40
# 252/255 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8259 - mae: 0.5182
# Epoch 4: val_loss improved from 0.99118 to 0.98913, saving model to /content/best_lean_pm10.keras
#
# Epoch 4: finished saving model to /content/best_lean_pm10.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.8229 - mae: 0.5160 - val_loss: 0.9891 - val_mae: 0.5814 - learning_rate: 3.0000e-04
# Epoch 5/40
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8100 - mae: 0.5094
# Epoch 5: val_loss did not improve from 0.98913
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8079 - mae: 0.5077 - val_loss: 0.9899 - val_mae: 0.5781 - learning_rate: 3.0000e-04
# Epoch 6/40
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7971 - mae: 0.5017
# Epoch 6: val_loss improved from 0.98913 to 0.98014, saving model to /content/best_lean_pm10.keras
#
# Epoch 6: finished saving model to /content/best_lean_pm10.keras
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.7949 - mae: 0.5000 - val_loss: 0.9801 - val_mae: 0.5758 - learning_rate: 3.0000e-04
# Epoch 7/40
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7864 - mae: 0.4950
# Epoch 7: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7830 - mae: 0.4927 - val_loss: 0.9938 - val_mae: 0.5795 - learning_rate: 3.0000e-04
# Epoch 8/40
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7723 - mae: 0.4866
# Epoch 8: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7714 - mae: 0.4857 - val_loss: 0.9835 - val_mae: 0.5740 - learning_rate: 3.0000e-04
# Epoch 9/40
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7602 - mae: 0.4782
# Epoch 9: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.7601 - mae: 0.4782 - val_loss: 1.0009 - val_mae: 0.5824 - learning_rate: 3.0000e-04
# Epoch 10/40
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7516 - mae: 0.4730
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 10: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7514 - mae: 0.4726 - val_loss: 1.0273 - val_mae: 0.5909 - learning_rate: 3.0000e-04
# Epoch 11/40
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7367 - mae: 0.4644
# Epoch 11: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7395 - mae: 0.4658 - val_loss: 1.0291 - val_mae: 0.5951 - learning_rate: 1.5000e-04
# Epoch 12/40
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7297 - mae: 0.4606
# Epoch 12: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.7338 - mae: 0.4628 - val_loss: 1.0378 - val_mae: 0.5941 - learning_rate: 1.5000e-04
# Epoch 13/40
# 253/255 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7263 - mae: 0.4580
# Epoch 13: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.7269 - mae: 0.4585 - val_loss: 1.0557 - val_mae: 0.6043 - learning_rate: 1.5000e-04
# Epoch 14/40
# 251/255 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7267 - mae: 0.4585
# Epoch 14: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 14: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.7261 - mae: 0.4580 - val_loss: 1.0458 - val_mae: 0.6003 - learning_rate: 1.5000e-04
# Epoch 15/40
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7158 - mae: 0.4513
# Epoch 15: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.7175 - mae: 0.4526 - val_loss: 1.0534 - val_mae: 0.6053 - learning_rate: 7.5000e-05
# Epoch 16/40
# 254/255 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7088 - mae: 0.4482
# Epoch 16: val_loss did not improve from 0.98014
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.7123 - mae: 0.4499 - val_loss: 1.0617 - val_mae: 0.6101 - learning_rate: 7.5000e-05
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %%
plt.figure(figsize=(12,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Training Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %%
def inverse_target_only(y_scaled_2d, scaler_obj, n_features, target_col_idx):
    out = []
    for i in range(len(y_scaled_2d)):
        dummy = np.zeros((y_scaled_2d.shape[1], n_features))
        dummy[:, target_col_idx] = y_scaled_2d[i]
        inv = scaler_obj.inverse_transform(dummy)[:, target_col_idx]
        out.append(inv)
    return np.array(out)

def smape(y_true, y_pred, eps=1e-6):
    return np.mean(2.0*np.abs(y_true-y_pred)/(np.abs(y_true)+np.abs(y_pred)+eps))*100

y_pred_scaled = model.predict(X_test, verbose=1)

n_features = len(feature_cols)
y_test_real = inverse_target_only(y_test, scaler, n_features, target_idx)
y_pred_real = inverse_target_only(y_pred_scaled, scaler, n_features, target_idx)

mae = mean_absolute_error(y_test_real.flatten(), y_pred_real.flatten())
rmse = np.sqrt(mean_squared_error(y_test_real.flatten(), y_pred_real.flatten()))
smape_v = smape(y_test_real, y_pred_real)

q75_real = np.quantile(y_test_real, 0.75)
peak_mask = y_test_real >= q75_real
peak_mae = np.mean(np.abs(y_test_real[peak_mask] - y_pred_real[peak_mask]))

d_true = np.abs(np.diff(y_test_real, axis=1))
d_pred = np.abs(np.diff(y_pred_real, axis=1))
ramp_mae = np.mean(np.abs(d_true - d_pred))

print("\n=== FINAL METRICS (Real µg/m³) ===")
print(f"MAE       : {mae:.4f}")
print(f"RMSE      : {rmse:.4f}")
print(f"sMAPE (%) : {smape_v:.4f}")
print(f"Peak MAE  : {peak_mae:.4f} (true >= Q75)")
print(f"Ramp MAE  : {ramp_mae:.4f}")




print("\n--- Пример: Споредба за првите 5 часа од еден тест примерок ---")
for i in range(5):
    print(f"Час {i+1} -> Вистинско: {y_test_real[0][i]:.1f} µg/m³ | Предвидено: {y_pred_real[0][i]:.1f} µg/m³")
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# === FINAL METRICS (Real µg/m³) ===
# MAE       : 3.3295
# RMSE      : 6.3229
# sMAPE (%) : 41.2847
# Peak MAE  : 6.4100 (true >= Q75)
# Ramp MAE  : 0.4842
#
# --- ФИНАЛНИ РЕЗУЛТАТИ ОД ЕВАЛУАЦИЈА (во реални µg/m³) ---
# 1. MAE (Просечна апсолутна грешка): 3.33 µg/m³
#    (Толку во просек промашува моделот кога предвидува за следните 24 часа)
# 2. RMSE (Корен од просечна квадратна грешка): 6.32 µg/m³
#
# --- Пример: Споредба за првите 5 часа од еден тест примерок ---
# Час 1 -> Вистинско: 10.6 µg/m³ | Предвидено: 10.9 µg/m³
# Час 2 -> Вистинско: 10.8 µg/m³ | Предвидено: 10.9 µg/m³
# Час 3 -> Вистинско: 11.0 µg/m³ | Предвидено: 11.0 µg/m³
# Час 4 -> Вистинско: 11.5 µg/m³ | Предвидено: 11.0 µg/m³
# Час 5 -> Вистинско: 12.0 µg/m³ | Предвидено: 11.2 µg/m³

# %%
idx = random.randint(0, len(y_test_real)-1)
plt.figure(figsize=(12,6))
plt.plot(range(1, HORIZON+1), y_test_real[idx], marker='o', label='True PM10')
plt.plot(range(1, HORIZON+1), y_pred_real[idx], marker='x', linestyle='--', label='Pred PM10')
plt.title(f'24h Forecast Sample #{idx}')
plt.xlabel('Hour Ahead')
plt.ylabel('PM10 (µg/m³)')
plt.xticks(range(1, HORIZON+1))
plt.grid(True, linestyle='--', alpha=0.4)
plt.legend()
plt.show()

# %%
log_file = '/content/experiments_log.csv'
experiment_name = 'LEAN_CNN_BiLSTM_Attn_PeakRampLoss'

log_data = {
    'date': [datetime.now().strftime("%Y-%m-%d %H:%M:%S")],
    'model_name': [experiment_name],
    'lookback': [LOOKBACK],
    'horizon': [HORIZON],
    'num_features': [len(feature_cols)],
    'selected_features': [", ".join(feature_cols)],
    'mae': [round(float(mae), 4)],
    'rmse': [round(float(rmse), 4)],
    'smape': [round(float(smape_v), 4)],
    'peak_mae': [round(float(peak_mae), 4)],
    'ramp_mae': [round(float(ramp_mae), 4)],
    'notes': ['Chronological split; RobustScaler; lean CNN+BiLSTM+attention pooling']
}
new_log_df = pd.DataFrame(log_data)

if os.path.isfile(log_file):
    new_log_df.to_csv(log_file, mode='a', index=False, header=False)
    print("\n✅ Appended to", log_file)
else:
    new_log_df.to_csv(log_file, index=False)
    print("\n🚀 Created", log_file)

display(pd.read_csv(log_file).tail(10))
# Out:
# 🚀 Created /content/experiments_log.csv
#                   date                         model_name  lookback  horizon  \
# 0  2026-03-27 17:10:51  LEAN_CNN_BiLSTM_Attn_PeakRampLoss        48       24
#
#    num_features                                  selected_features     mae  \
# 0            14  pm10, pm2_5, aqi, hour_sin, hour_cos, day_sin,...  3.3295
#
#      rmse    smape  peak_mae  ramp_mae  \
# 0  6.3229  41.2847      6.41    0.4842
#
#                                                notes
# 0  Chronological split; RobustScaler; lean CNN+Bi...

# %%
import os
import json
import pickle
import pandas as pd
import shutil
from datetime import datetime

# ---------- REQUIRED OBJECTS ----------
ARTIFACT_DIR = "/content/pm10_artifacts"
os.makedirs(ARTIFACT_DIR, exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
run_name = f"pm10_lean_{timestamp}"

# ---- 1) Save model ----
model_path = os.path.join(ARTIFACT_DIR, f"{run_name}.keras")
model.save(model_path)
print(f"✅ Моделот е зачуван: {model_path}")

# ---- 2) Save scaler ----
scaler_path = os.path.join(ARTIFACT_DIR, f"{run_name}_scaler.pkl")
with open(scaler_path, "wb") as f:
    pickle.dump(scaler, f)
print(f"✅ Скалерот е зачуван: {scaler_path}")

# ---- 3) Save feature importance if available ----
importance_path = None
if "importance" in globals() and isinstance(importance, pd.Series):
    importance_path = os.path.join(ARTIFACT_DIR, f"{run_name}_feature_importance.csv")
    importance.sort_values(ascending=False).to_csv(importance_path, header=["importance"])
    print(f"✅ Важноста на карактеристиките е зачувана: {importance_path}")

# ---- 4) Save metadata/config for inference ----
meta = {
    "run_name": run_name,
    "saved_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "target_col": TARGET_COL,
    "target_idx": int(target_idx),
    "feature_cols": list(feature_cols),
    "n_features": int(len(feature_cols)),
    "lookback": int(LOOKBACK),
    "horizon_trained": int(HORIZON),
    "notes": "Ова е финалниот оптимизиран модел."
}

meta_path = os.path.join(ARTIFACT_DIR, f"{run_name}_meta.json")
with open(meta_path, "w") as f:
    json.dump(meta, f, indent=2)
print(f"✅ Метаподатоците се зачувани: {meta_path}")

# ---- 5) Save selected features alone ----
features_path = os.path.join(ARTIFACT_DIR, f"{run_name}_selected_features.json")
with open(features_path, "w") as f:
    json.dump({"selected_features": list(feature_cols)}, f, indent=2)
print(f"✅ Избраните карактеристики се зачувани: {features_path}")

zip_base_path = f"/content/{run_name}_bundle"
shutil.make_archive(zip_base_path, 'zip', ARTIFACT_DIR)
print(f"📦 СИ ЗИПОВАНО! Фајлот е спремен за симнување: {zip_base_path}.zip")
# Out:
# ✅ Моделот е зачуван: /content/pm10_artifacts/pm10_lean_20260327_171406.keras
# ✅ Скалерот е зачуван: /content/pm10_artifacts/pm10_lean_20260327_171406_scaler.pkl
# ✅ Важноста на карактеристиките е зачувана: /content/pm10_artifacts/pm10_lean_20260327_171406_feature_importance.csv
# ✅ Метаподатоците се зачувани: /content/pm10_artifacts/pm10_lean_20260327_171406_meta.json
# ✅ Избраните карактеристики се зачувани: /content/pm10_artifacts/pm10_lean_20260327_171406_selected_features.json
# 📦 СИ ЗИПОВАНО! Фајлот е спремен за симнување: /content/pm10_lean_20260327_171406_bundle.zip
